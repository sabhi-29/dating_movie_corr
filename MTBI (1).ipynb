# %%
personality_descriptions = {
        'ISTJ': 'The Inspector - ISTJs are responsible organizers, driven to create order and stability.',
        'ISFJ': 'Quiet, friendly, responsible, and conscientious. Committed and steady in meeting their obligations. Thorough, painstaking, and accurate. Loyal, considerate, notice and remember specifics about people who are important to them, concerned with how others feel. Strive to create an orderly and harmonious environment at work and at home.',
        'INFJ': 'Seek meaning and connection in ideas, relationships, and material possessions. Want to understand what motivates people and are insightful about others. Conscientious and committed to their firm values. Develop a clear vision about how best to serve the common good. Organized and decisive in implementing their vision.',
        'INTJ': 'Have original minds and great drive for implementing their ideas and achieving their goals. Quickly see patterns in external events and develop long-range explanatory perspectives. When committed, organize a job and carry it through. Skeptical and independent, have high standards of competence and performance—for themselves and others.',
        'ISTJ': 'Quiet, serious, earn success by being thorough and dependable. Practical, matter-of-fact, realistic, and responsible. Decide logically what should be done and work toward it steadily, regardless of distractions. Take pleasure in making everything orderly and organized—their work, their home, their life. Value traditions and loyalty.',
        'ISTP': 'Tolerant and flexible, quiet observers until a problem appears, then act quickly to find workable solutions. Analyze what makes things work and readily get through large amounts of data to isolate the core of practical problems. Interested in cause and effect, organize facts using logical principles, value efficiency.',
        'ISFP': "Quiet, friendly, sensitive, and kind. Enjoy the present moment, what's going on around them. Like to have their own space and to work within their own time frame. Loyal and committed to their values and to people who are important to them. Dislike disagreements and conflicts; don't force their opinions or values on others.",
        'INFP': "Idealistic, loyal to their values and to people who are important to them. Want to live a life that is congruent with their values. Curious, quick to see possibilities, can be catalysts for implementing ideas. Seek to understand people and to help them fulfill their potential. Adaptable, flexible, and accepting unless a value is threatened.",
        'INTP': "Seek to develop logical explanations for everything that interests them. Theoretical and abstract, interested more in ideas than in social interaction. Quiet, contained, flexible, and adaptable. Have unusual ability to focus in depth to solve problems in their area of interest. Skeptical, sometimes critical, always analytical.",
        'ESTP': "Flexible and tolerant, take a pragmatic approach focused on immediate results. Bored by theories and conceptual explanations; want to act energetically to solve the problem. Focus on the here and now, spontaneous, enjoy each moment they can be active with others. Enjoy material comforts and style. Learn best through doing.",
        'ESFP': "Outgoing, friendly, and accepting. Exuberant lovers of life, people, and material comforts. Enjoy working with others to make things happen. Bring common sense and a realistic approach to their work and make work fun. Flexible and spontaneous, adapt readily to new people and environments. Learn best by trying a new skill with other people.",
        'ENFP': "Warmly enthusiastic and imaginative. See life as full of possibilities. Make connections between events and information very quickly, and confidently proceed based on the patterns they see. Want a lot of affirmation from others, and readily give appreciation and support. Spontaneous and flexible, often rely on their ability to improvise and their verbal fluency.",
        'ENTP': "Quick, ingenious, stimulating, alert, and outspoken. Resourceful in solving new and challenging problems. Adept at generating conceptual possibilities and then analyzing them strategically. Good at reading other people. Bored by routine, will seldom do the same thing the same way, apt to turn to one new interest after another.",
        'ESTJ': "Practical, realistic, matter-of-fact. Decisive, quickly move to implement decisions. Organize projects and people to get things done, focus on getting results in the most efficient way possible. Take care of routine details. Have a clear set of logical standards, systematically follow them and want others to also. Forceful in implementing their plans.",
        'ESFJ': "Warmhearted, conscientious, and cooperative. Want harmony in their environment, work with determination to establish it. Like to work with others to complete tasks accurately and on time. Loyal, follow through even in small matters. Notice what others need in their day-to-day lives and try to provide it. Want to be appreciated for who they are and for what they contribute.",
        'ENFJ': "Warm, empathetic, responsive, and responsible. Highly attuned to the emotions, needs, and motivations of others. Find potential in everyone, want to help others fulfill their potential. May act as catalysts for individual and group growth. Loyal, responsive to praise and criticism. Sociable, facilitate others in a group, and provide inspiring leadership.",
        'ENTJ': "Frank, decisive, assume leadership readily. Quickly see illogical and inefficient procedures and policies, develop and implement comprehensive systems to solve organizational problems. Enjoy long-term planning and goal setting. Usually well informed, well read, enjoy expanding their knowledge and passing it on to others. Forceful in presenting their ideas."
    }

def get_personality_description(mbti_type):
    personality_descriptions = {
        'ISTJ': 'The Inspector - ISTJs are responsible organizers, driven to create order and stability.',
        'ISFJ': 'Quiet, friendly, responsible, and conscientious. Committed and steady in meeting their obligations. Thorough, painstaking, and accurate. Loyal, considerate, notice and remember specifics about people who are important to them, concerned with how others feel. Strive to create an orderly and harmonious environment at work and at home.',
        'INFJ': 'Seek meaning and connection in ideas, relationships, and material possessions. Want to understand what motivates people and are insightful about others. Conscientious and committed to their firm values. Develop a clear vision about how best to serve the common good. Organized and decisive in implementing their vision.',
        'INTJ': 'Have original minds and great drive for implementing their ideas and achieving their goals. Quickly see patterns in external events and develop long-range explanatory perspectives. When committed, organize a job and carry it through. Skeptical and independent, have high standards of competence and performance—for themselves and others.',
        'ISTJ': 'Quiet, serious, earn success by being thorough and dependable. Practical, matter-of-fact, realistic, and responsible. Decide logically what should be done and work toward it steadily, regardless of distractions. Take pleasure in making everything orderly and organized—their work, their home, their life. Value traditions and loyalty.',
        'ISTP': 'Tolerant and flexible, quiet observers until a problem appears, then act quickly to find workable solutions. Analyze what makes things work and readily get through large amounts of data to isolate the core of practical problems. Interested in cause and effect, organize facts using logical principles, value efficiency.',
        'ISFP': "Quiet, friendly, sensitive, and kind. Enjoy the present moment, what's going on around them. Like to have their own space and to work within their own time frame. Loyal and committed to their values and to people who are important to them. Dislike disagreements and conflicts; don't force their opinions or values on others.",
        'INFP': "Idealistic, loyal to their values and to people who are important to them. Want to live a life that is congruent with their values. Curious, quick to see possibilities, can be catalysts for implementing ideas. Seek to understand people and to help them fulfill their potential. Adaptable, flexible, and accepting unless a value is threatened.",
        'INTP': "Seek to develop logical explanations for everything that interests them. Theoretical and abstract, interested more in ideas than in social interaction. Quiet, contained, flexible, and adaptable. Have unusual ability to focus in depth to solve problems in their area of interest. Skeptical, sometimes critical, always analytical.",
        'ESTP': "Flexible and tolerant, take a pragmatic approach focused on immediate results. Bored by theories and conceptual explanations; want to act energetically to solve the problem. Focus on the here and now, spontaneous, enjoy each moment they can be active with others. Enjoy material comforts and style. Learn best through doing.",
        'ESFP': "Outgoing, friendly, and accepting. Exuberant lovers of life, people, and material comforts. Enjoy working with others to make things happen. Bring common sense and a realistic approach to their work and make work fun. Flexible and spontaneous, adapt readily to new people and environments. Learn best by trying a new skill with other people.",
        'ENFP': "Warmly enthusiastic and imaginative. See life as full of possibilities. Make connections between events and information very quickly, and confidently proceed based on the patterns they see. Want a lot of affirmation from others, and readily give appreciation and support. Spontaneous and flexible, often rely on their ability to improvise and their verbal fluency.",
        'ENTP': "Quick, ingenious, stimulating, alert, and outspoken. Resourceful in solving new and challenging problems. Adept at generating conceptual possibilities and then analyzing them strategically. Good at reading other people. Bored by routine, will seldom do the same thing the same way, apt to turn to one new interest after another.",
        'ESTJ': "Practical, realistic, matter-of-fact. Decisive, quickly move to implement decisions. Organize projects and people to get things done, focus on getting results in the most efficient way possible. Take care of routine details. Have a clear set of logical standards, systematically follow them and want others to also. Forceful in implementing their plans.",
        'ESFJ': "Warmhearted, conscientious, and cooperative. Want harmony in their environment, work with determination to establish it. Like to work with others to complete tasks accurately and on time. Loyal, follow through even in small matters. Notice what others need in their day-to-day lives and try to provide it. Want to be appreciated for who they are and for what they contribute.",
        'ENFJ': "Warm, empathetic, responsive, and responsible. Highly attuned to the emotions, needs, and motivations of others. Find potential in everyone, want to help others fulfill their potential. May act as catalysts for individual and group growth. Loyal, responsive to praise and criticism. Sociable, facilitate others in a group, and provide inspiring leadership.",
        'ENTJ': "Frank, decisive, assume leadership readily. Quickly see illogical and inefficient procedures and policies, develop and implement comprehensive systems to solve organizational problems. Enjoy long-term planning and goal setting. Usually well informed, well read, enjoy expanding their knowledge and passing it on to others. Forceful in presenting their ideas."
    }

    mbti_type = mbti_type.upper()
    if mbti_type in personality_descriptions:
        return personality_descriptions[mbti_type]
    else:
        return f"Description not available for MBTI type: {mbti_type}"

# Example usage
mbti_type_input = 'ENFP'
description = get_personality_description(mbti_type_input)
print(description)
# Out:
# Warmly enthusiastic and imaginative. See life as full of possibilities. Make connections between events and information very quickly, and confidently proceed based on the patterns they see. Want a lot of affirmation from others, and readily give appreciation and support. Spontaneous and flexible, often rely on their ability to improvise and their verbal fluency.

# %%
import pandas as pd
f_df = pd.read_csv('model_3_dm.csv')

# %%
f_df
# Out:
#      level_0 level_1 Prominent_Genre  \
# 0      18-24       F          Comedy
# 1      18-24       M          Comedy
# 2      25-34       F           Drama
# 3      25-34       M          Comedy
# 4      35-44       F           Drama
# 5      35-44       M           Drama
# 6      45-49       F           Drama
# 7      45-49       M           Drama
# 8      50-55       F           Drama
# 9      50-55       M           Drama
# 10       56+       F           Drama
# 11       56+       M           Drama
# 12  Under 18       F          Comedy
# 13  Under 18       M          Comedy
#
#                                        Popular_Movies  \
# 0   ['American Beauty (1999)', 'Shakespeare in Lov...
# 1   ['American Beauty (1999)', 'Men in Black (1997...
# 2   ['American Beauty (1999)', 'Silence of the Lam...
# 3   ['American Beauty (1999)', 'Men in Black (1997...
# 4   ['American Beauty (1999)', 'Silence of the Lam...
# 5   ['Star Wars: Episode V - The Empire Strikes Ba...
# 6   ['American Beauty (1999)', 'Silence of the Lam...
# 7   ['American Beauty (1999)', 'Star Wars: Episode...
# 8   ['American Beauty (1999)', 'Fargo (1996)', 'Go...
# 9   ['American Beauty (1999)', 'Star Wars: Episode...
# 10  ['American Beauty (1999)', "Schindler's List (...
# 11  ['American Beauty (1999)', "Schindler's List (...
# 12  ['Toy Story (1995)', 'Aladdin (1992)', 'Toy St...
# 13  ['Toy Story (1995)', 'Men in Black (1997)', 'T...
#
#                                    Movies of Interest  \
# 0   ['american beauty', 'shakespeare in love', 'th...
# 1   ['american beauty', 'men in black', 'being joh...
# 2   ['american beauty', 'the silence of the lambs'...
# 3   ['american beauty', 'men in black', 'the princ...
# 4   ['american beauty', 'the silence of the lambs'...
# 5   ['american beauty', 'saving private ryan', 'th...
# 6   ['american beauty', 'the silence of the lambs'...
# 7   ['american beauty', 'the godfather', 'saving p...
# 8   ['american beauty', 'fargo', 'the godfather', ...
# 9   ['american beauty', 'braveheart', 'the godfath...
# 10  ['american beauty', "schindler's list", 'savin...
# 11  ['american beauty', "schindler's list", 'fargo...
# 12    ['toy story', 'aladdin', 'shakespeare in love']
# 13  ['toy story', 'men in black', 'american beauty...
#
#                                     Personality Count  \
# 0   {'ISFP': 3, 'ENFP': 3, 'ESTJ': 3, 'INTP': 3, '...
# 1   {'ESTJ': 2, 'ISFP': 2, 'INTJ': 2, 'ESFP': 1, '...
# 2   {'ESTP': 6, 'ISTJ': 4, 'ISTP': 3, 'ISFP': 3, '...
# 3   {'ISFJ': 12, 'ISFP': 8, 'INFJ': 5, 'ESTJ': 4, ...
# 4   {'INFP': 2, 'No personality': 2, 'ISTJ': 2, 'E...
# 5   {'ISFJ': 13, 'ISFP': 10, 'INFJ': 5, 'ESTJ': 4,...
# 6   {'ISTJ': 32, 'ESTJ': 24, 'ESTP': 20, 'No perso...
# 7   {'ISFJ': 13, 'ISFP': 10, 'INFJ': 5, 'ESFJ': 4,...
# 8   {'ESTP': 9, 'ISTJ': 7, 'ENTJ': 5, 'ISTP': 5, '...
# 9   {'ISFJ': 13, 'ISFP': 10, 'INFJ': 5, 'ESFJ': 4,...
# 10  {'ISTJ': 3, 'INFP': 2, 'ENTJ': 2, 'ESTP': 2, '...
# 11  {'ISFJ': 13, 'ISFP': 10, 'INFJ': 5, 'ESFJ': 4,...
# 12  {'INTP': 3, 'ENFP': 3, 'ISTP': 3, 'ESFP': 2, '...
# 13  {'ESFP': 3, 'ISFP': 3, 'ISFJ': 2, 'ENFJ': 2, '...
#
#                 Most Prominent Personalities
# 0   ['ISFP', 'ENFP', 'ESTJ', 'INTP', 'ISTP']
# 1                   ['ESTJ', 'ISFP', 'INTJ']
# 2                           ['ESTP', 'ISTJ']
# 3                           ['ISFJ', 'ISFP']
# 4   ['INFP', 'ISTJ', 'ESTP', 'ESFJ', 'ISTP']
# 5                           ['ISFJ', 'ISFP']
# 6                           ['ISTJ', 'ESTJ']
# 7                           ['ISFJ', 'ISFP']
# 8                           ['ESTP', 'ISTJ']
# 9                           ['ISFJ', 'ISFP']
# 10                                  ['ISTJ']
# 11                          ['ISFJ', 'ISFP']
# 12                  ['INTP', 'ENFP', 'ISTP']
# 13                          ['ESFP', 'ISFP']

# %%
ok_cupid_words = pd.read_csv('ok_cupid_words.csv')

# %%
ok_cupid_words
# Out:
#       Age Gender                                    Important_Words
# 0   18-24      f  ['adventure', 'good', 'message', 'think', 'lov...
# 1   18-24      m  ['like', 'message', 'talk', 'look', 'fun', 'ne...
# 2   25-34      f  ['think', 'love', 'intrested', 'friend', 'time...
# 3   25-34      m  ['think', 'talk', 'cool', 'adventure', 'work',...
# 4   35-44      f  ['relationship', 'enjoy', 'smart', 'date', 're...
# 5   35-44      m  ['good', 'love', 'open', 'great', 'relationshi...
# 6   45-49      f  ['physical', 'afraid', 'creative', 'family', '...
# 7   45-49      m  ['fun', 'conversation', 'appreciate', 'travel'...
# 8   50-55      f  ['creative', 'integrity', 'spiritual', 'availa...
# 9   50-55      m  ['sexy', 'spirit', 'desire', 'dance', 'strong'...
# 10    56+      f  ['family', 'single', 'attractive', 'compassion...
# 11    56+      m  ['soul', 'kiss', 'lover', 'respect', 'respond'...

# %%
ok_cupid_words['Important_Words'][0]
# Out:
# "['adventure', 'good', 'message', 'think', 'love', 'fun', 'new', 'friend', 'music', 'talk', 'people', 'interested', 'enjoy', 'conversation', 'read', 'interesting', 'laugh']"

# %%
import ast
string_representation = "['adventure', 'good', 'message', 'think', 'love', 'fun', 'new', 'friend', 'music', 'talk', 'people', 'interested', 'enjoy', 'conversation', 'read', 'interesting', 'laugh']"

# Convert string to a list using ast.literal_eval
list_from_string = ast.literal_eval(string_representation)

print(list_from_string)
# Out:
# ['adventure', 'good', 'message', 'think', 'love', 'fun', 'new', 'friend', 'music', 'talk', 'people', 'interested', 'enjoy', 'conversation', 'read', 'interesting', 'laugh']

# %%
# Sample sentence and list of words
sentence = personality_descriptions['ENFP']
word_list = ast.literal_eval(ok_cupid_words['Important_Words'][0])

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/42.8 MB 1.7 MB/s eta 0:00:22
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/http/client.py", line 466, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/ssl.py", line 1278, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/ssl.py", line 1134, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/cli/base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/cli/req_command.py", line 248, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 293, in __init__
#     super().__init__(
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/operations/prepare.py", line 538, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/operations/prepare.py", line 609, in _prepare_linked_requirement
#     local_file = unpack_url(
#                  ^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/operations/prepare.py", line 166, in unpack_url
#     file = get_http_url(
#            ^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/operations/prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/network/download.py", line 147, in __call__
#     for chunk in chunks:
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/cli/progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     with self._error_catcher():
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/contextlib.py", line 155, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/bhargavsaibhuvanagiri/anaconda3/lib/python3.11/site-packages/pip/_vendor/urllib3/response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='objects.githubusercontent.com', port=443): Read timed out.

# %%
import spacy


# Load the English language model in spaCy
nlp = spacy.load('en_core_web_md')

# Process the sentence to get its word embeddings
doc = nlp(sentence)

# Calculate similarity between each word in the list and the sentence
similarities = []
for word in word_list:
    token = nlp(word)
    similarity = token.similarity(doc)
    # Doubling similarity values greater than 0.5
#     if similarity > 0.5:
#             similarity *= 2  # Double the similarity value

    similarities.append(similarity)
print(similarities)
avg = sum(similarities)/len(similarities)
# Determine if any word in the list is similar to words in the sentence based on a threshold
threshold = 0.65  # Adjust this threshold as needed
if any(similarity >= threshold for similarity in similarities):
    print("Some words in the list are similar to words in the sentence.")
else:
    print("No words in the list are similar to words in the sentence.")
# Out:
# [0.4069955116063634, 0.38709131596809954, 0.33092959324478616, 0.3407672923958169, 0.23959797194152638, 0.06343948427812793, 0.44549337541652095, 0.2220303851589079, 0.30396339508679393, 0.18502674249251982, 0.47200963206351465, 0.6243949571262949, 0.28961970075827215, 0.660088947207178, 0.1727333495142683, 0.7419745617264412, -0.004178090311631953]
# Some words in the list are similar to words in the sentence.

# %%
#i should take the sentence and comapre it with the words list

# %%
import spacy

# Load the English language model in spaCy
nlp = spacy.load('en_core_web_md')
threshold = 0.5
# List to store average similarities
count=[]
word_list = ast.literal_eval(ok_cupid_words['Important_Words'][9])
# Iterate through each sentence in the dictionary
for sentence_key, sentence_value in personality_descriptions.items():
    # Process the sentence to get its word embeddings
    doc = nlp(sentence_value)

    # Calculate similarity between each word in the list and the sentence
    similarities = []
    for word in word_list:
        token = nlp(word)
        similarity = token.similarity(doc)
        if similarity > threshold:
            similarities.append(similarity)
    count.append(len(similarities))
    # Calculate average similarity for the current sentence and word list
#     avg_similarity = sum(similarities) / len(similarities)
#     average_similarities.append((sentence_key, avg_similarity))

# Displaying the list of average similarities
print(count)
#0 0.5
#1 no
#2 prob 0.5 include
#3 prob = 0.5 not convincing
#4 include
#5 no include
#6 not that covincing
#7 no include
#8 include
#9  include
#10  nope
#11  nope
# Out:
# [4, 4, 5, 4, 4, 5, 6, 4, 5, 6, 4, 4, 4, 6, 4, 6]

# %%
codes = personality_descriptions.keys()

# %%
print(codes)
# Out:
# dict_keys(['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP', 'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ'])

# %%
codes = list(codes)

# %%
print(codes)
# Out:
# ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP', 'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']

# %%
import matplotlib.pyplot as plt

# Given data
Y = count
X = ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP', 'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']

# Creating the line chart
plt.figure(figsize=(10, 6))
plt.plot(X, Y, marker='o', linestyle='-', color='b')

# Adding title and labels
plt.title('Count Similarity for Sentences with Word List')
plt.xlabel('Personality Types')
plt.ylabel('Count Similarity')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()
